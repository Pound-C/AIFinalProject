# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn import preprocessing
from sklearn.linear_model import SGDRegressor,LinearRegression,RidgeCV,LassoCV,ElasticNetCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings("ignore")

# %%
import logging
log_path = "PhishingLink\\task_log.txt"

logging.basicConfig(
    filename=log_path,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

logging.info(f"Tranco Crashes Today")

# %%
with open('linkedin_jobs.csv') as data:
    reader = pd.read_csv('linkedin_jobs.csv', encoding='utf-8-sig')
reader.dropna()
# Out:
#                                             Title  \
# 0    Leave Resume Here (Data Science & Analytics)
# 1                      Data Scientist (Mid level)
# 2                       Machine Learning Engineer
# 3                           Junior Data Scientist
# 6                                  Data Scientist
# ..                                            ...
# 111         Research Scientist, Quantum Chemistry
# 114                             Software Engineer
# 115            เจ้าหน้าที่วิเคราะห์ข้อมูล(ตัวเลข)
# 116              IT Developer, Chemicals Business
# 117                         Application Developer
#
#                              Company                               Location  \
# 0                                SCG                 Bangkok City, Thailand
# 1                             Sertis        Bangkok, Bangkok City, Thailand
# 2                             Sertis        Bangkok, Bangkok City, Thailand
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("ealvaradob/phishing-dataset", "aklskndkasnkd", trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset("ealvaradob/phishing-dataset", "aklskndkasnkd", trust_remote_code=True)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\datasets\load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
#    2064     name=name,
# ...

# %%
dataset['train'].to_pandas()
# Out:
#                                                     text  label
# 0      <!doctypehtml><html lang=en xml:lang=en xmlns=...      0
# 1                      http://online0mgeving.ga/triodos/      1
# 2      metronews.ca/webapp/Login.aspx?logout=true&rur...      0
# 3          https://rarkuntem.co.jp.fpjiehk.cn/index1.php      1
# 4                            freebase.com/view/m/0ct05qn      0
# ...                                                  ...    ...
# 77672         http://www.definitions.net/definition/icon      0
# 77673  schedule crawler : hourahead failure start dat...      0
# 77674  <!doctypehtml PUBLIC "-//W3C//DTD HTML+RDFa 1....      0
# 77675  amazon.com/Sound-Horror-James-Philbrook/dp/B00...      0
# 77676  music.yahoo.com/arashi/albums/monster-single--...      0
#
# [77677 rows x 2 columns]

# %%
import requests
import json

# Replace this with your actual PhishTank API key
API_KEY = "YOUR_API_KEY"

# Replace this with the URL you want to check
url_to_check = "http://example.com"

# PhishTank API endpoint
url = "https://checkurl.phishtank.com/checkurl/"

# Prepare the payload
data = {
    "url": url_to_check,
    "format": "json",
    "app_key": API_KEY
}

# Make the POST request
response = requests.post(url, data=data)

# Check for success
if response.status_code == 200:
    result = response.json()
    print(json.dumps(result, indent=4))  # Nicely formatted output
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Error: 403 - <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;max-width:60rem;padding-left:1.5rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{font-size:1.5rem;font-weight:500;line-height:2.25rem}@media (width <= 720px){.h2{font-size:1.25rem;line-height:1.5rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,.
# ...
